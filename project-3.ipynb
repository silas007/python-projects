# %%
import pandas as pd
import numpy as nd
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
from sklearn.preprocessing import MinMaxScaler,StandardScaler

# %%
df = pd.read_csv(r"C:\Users\ADMIN\Downloads\Scaling_cars (1).csv" )

# %%
df.head()
# Out:
#           Car       Model  Volume  Weight  CO2
# 0      Toyoty        Aygo     1.0     790   99
# 1  Mitsubishi  Space Star     1.2    1160   95
# 2       Skoda      Citigo     1.0     929   95
# 3        Fiat         500     0.9     865   90
# 4        Mini      Cooper     1.5    1140  105

# %%
plt.scatter(df.Volume, df.	Weight)
plt.axvline(x=0,c="red",label="x=0")
plt.axhline(y=0,c="yellow",label="y=0")
plt.show()

# %%
data = {
    'Volume': [1.0, 1.2, 1.0, 0.9, 1.5],
    'Weight': [790, 1160, 929, 865, 1140]}
data
# Out:
# {'Volume': [1.0, 1.2, 1.0, 0.9, 1.5], 'Weight': [790, 1160, 929, 865, 1140]}

# %%
df_subset = pd.DataFrame(data)

# %%
scaler = MinMaxScaler()
min_max_scaled = scaler.fit_transform(df_subset)
min_max_scaled
# Out:
# array([[0.16666667, 0.        ],
#        [0.5       , 1.        ],
#        [0.16666667, 0.37567568],
#        [0.        , 0.2027027 ],
#        [1.        , 0.94594595]])

# %%
std = StandardScaler()
std_stand = std.fit_transform(df_subset)
df_standard =  pd.DataFrame(std_stand, columns=['Volume', 'Weight'])
df_standard
# Out:
#      Volume    Weight
# 0 -0.561951 -1.260123
# 1  0.374634  1.235838
# 2 -0.561951 -0.322451
# 3 -1.030244 -0.754185
# 4  1.779513  1.100921

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15, 5))
plt.subplot(1,2,1)
plt.scatter( df.Volume, df.Weight)
plt.axvline(x=0, c="red", label="x=0")
plt.axhline(y=0, c="yellow", label="y=0")
plt.subplot(1,2,2)
plt.scatter(min_max_scaled[:,0], min_max_scaled[:,1])
plt.show()

# %%
mm_scaler = MinMaxScaler()
mm_scaled = mm_scaler.fit_transform(df_subset)
df_minmax = pd.DataFrame(mm_scaled, columns=['Volume', 'Weight'])
df_minmax
# Out:
#      Volume    Weight
# 0  0.166667  0.000000
# 1  0.500000  1.000000
# 2  0.166667  0.375676
# 3  0.000000  0.202703
# 4  1.000000  0.945946

# %%
plt.subplot(1,2,2)
plt.scatter(df_minmax.Volume, df_minmax.Weight, color='green', s=100)
plt.title("Min-Max Scaled Data")

plt.show()
